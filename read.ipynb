# %%
import pandas as pd                                                                                                                                             
df = pd.read_parquet('data/processed/pwm.parquet')                                                                                                              
print(df.head())                                                                                                                                                
print(df.dtypes)                                                                                                                                                
print(f'Shape: {df.shape}')
